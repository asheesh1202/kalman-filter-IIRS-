# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# %%
def load_doc(filename):
    # open the file as read only
    file = open(filename, mode='rt', encoding='utf-8')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
# split a loaded document into sentences
def to_sentences(doc):
    return doc.strip().split('\n')

# shortest and longest sentence lengths
def sentence_lengths(sentences):
    lengths = [len(s.split()) for s in sentences]
    return min(lengths), max(lengths)

# %%
eng_file = "training.hi-en.en"
eng = load_doc(eng_file)
eng_sentences = to_sentences(eng)
min_len, max_len = sentence_lengths(eng_sentences)

# %%
print ("No. of sentences in english doc :") 
print (len(eng_sentences))  
print ("max lenght :")
print (max_len)
print ("min lenght :")
print (min_len)
# Out:
# No. of sentences in english doc :
# 37726
# max lenght :
# 433
# min lenght :
# 1

# %%
hindi_file="training.hi-en.hi"
hindi=load_doc(hindi_file)
hindi_sentences=to_sentences(hindi)
min_len, max_len=sentence_lengths(hindi_sentences)

# %%
print ("No. of sentences in hindi doc :") 
print (len(eng_sentences))  
print ("max lenght :")
print (max_len)
print ("min lenght :")
print (min_len)
# Out:
# No. of sentences in hindi doc :
# 37726
# max lenght :
# 435
# min lenght :
# 1

# %%
hindi_sentences[:10]
# Out:
# ['श्रेणी : धर्मग्रन्थ',
#  'श्रेणी : धर्मग्रन्थ',
#  'श्रेणी : धर्मग्रन्थ',
#  'श्रेणी : धर्मग्रन्थ',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।',
#  'पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।']

# %%
# clean a list of lines
def clean_lines(lines):
    cleaned = list()
    # prepare regex for char filtering
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for line in lines:
        # normalize unicode characters
        line = normalize('NFD', line).encode('ascii', 'ignore')
        line = line.decode('UTF-8')
        # tokenize on white space
        line = line.split()
            # convert to lower case
        line = [word.lower() for word in line]
        # remove punctuation from each token
        line = [word.translate(table) for word in line]
        # remove non-printable chars form each token
        line = [re_print.sub('', w) for w in line]
        # remove tokens with numbers in them
        line = [word for word in line if word.isalpha()]
        # store as string
        cleaned.append(' '.join(line))
    return cleaned


# save a list of clean sentences to file
def save_clean_sentences(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
eng_sentences = clean_lines(eng_sentences)
save_clean_sentences(eng_sentences, 'english.pkl')
# spot check
for i in range(10):
    print(eng_sentences[i])
# Out:
# Saved: english.pkl
# series religious book
# category religious text
# sat religious book
# division holy writ
# daliy hindi news bundelkhand s first web based paper
# daily hindi news first interconnect place of bundelkhand
# daily hindi news the first international news headlines of bundelkhand
# daily hindi news the first interdistrict place of bundelkhand lrb the first interdistrict terrestrial paper of bundelkhand rrb
# according to pakistan government this is the time seeds of pakistan were sown
# according to the government of pakistan this was the time that the foundation of pakistan had been laid

# %%
hindi_sentences[:10]
# Out:
# ['श्रेणी : धर्मग्रन्थ',
#  'श्रेणी : धर्मग्रन्थ',
#  'श्रेणी : धर्मग्रन्थ',
#  'श्रेणी : धर्मग्रन्थ',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'डेली हिन्दी न्यूज - बुंदेलखंड का प्रथम अन्तरजालीय स्थल',
#  'पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।',
#  'पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।']

# %%
def clean_lines(lines):
    cleaned = list()
    # prepare regex for char filtering
    #re_print = re.compile('[^%s]' % re.escape(string.printable))
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for line in lines:
        # normalize unicode characters
        #line = normalize('NFD', line).encode('ascii', 'ignore')
        #line = line.decode('UTF-8')
        # tokenize on white space
        line = line.split()
            # convert to lower case
        #line = [word.lower() for word in line]
        # remove punctuation from each token
        line = [word.translate(table) for word in line]
        # remove non-printable chars form each token
        #line = [re_print.sub('', w) for w in line]
        # remove tokens with numbers in them
        #line = [word for word in line if word.isalpha()]
        # store as string
        cleaned.append(' '.join(line))
    return cleaned


# save a list of clean sentences to file
def save_clean_sentences(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
hindi_sentences = clean_lines(hindi_sentences)
save_clean_sentences(hindi_sentences, 'hindi.pkl')
# spot check
for i in range(10):
    print(hindi_sentences[i])
# Out:
# Saved: hindi.pkl
# श्रेणी  धर्मग्रन्थ
# श्रेणी  धर्मग्रन्थ
# श्रेणी  धर्मग्रन्थ
# श्रेणी  धर्मग्रन्थ
# डेली हिन्दी न्यूज  बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# डेली हिन्दी न्यूज  बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# डेली हिन्दी न्यूज  बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# डेली हिन्दी न्यूज  बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।
# पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।

# %%
# load a clean dataset
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))

# %%
from pickle import load
from pickle import dump
from collections import Counter

# %%
# save a list of clean sentences to file
def save_clean_sentences(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
def to_vocab(lines):
    vocab = Counter()
    for line in lines:
        tokens = line.split()
        vocab.update(tokens)
    return vocab

# %%
# remove all words with a frequency below a threshold
def trim_vocab(vocab, min_occurance):
    tokens = [k for k,c in vocab.items() if c >= min_occurance]
    return set(tokens)

# %%
# mark all OOV with "unk" for all lines
def update_dataset(lines, vocab):
    new_lines = list()
    for line in lines:
        new_tokens = list()
        for token in line.split():
            if token in vocab:
                new_tokens.append(token)
            else:
                new_tokens.append('unk')
        new_line = ' '.join(new_tokens)
        new_lines.append(new_line)
    return new_lines

# %%
# load English dataset
eng = 'english.pkl'
eng_lines = load_clean_sentences(eng)
# calculate vocabulary
eng_vocab = to_vocab(eng_lines)
print('English Vocabulary: %d' % len(eng_vocab))
# reduce vocabulary
eng_vocab = trim_vocab(eng_vocab, 3)
print('New English Vocabulary: %d' % len(eng_vocab))
# mark out of vocabulary words
eng_lines = update_dataset(eng_lines, eng_vocab)
# save updated dataset
filename = 'english_vocab.pkl'
save_clean_sentences(eng_lines, filename)
# spot check
for i in range(1000):
    print(eng_lines[i])
# Out:
# English Vocabulary: 32929
# New English Vocabulary: 11933
# Saved: english_vocab.pkl
# series religious book
# category religious text
# sat religious book
# division holy writ
# unk hindi news bundelkhand s first web based paper
# daily hindi news first unk place of bundelkhand
# daily hindi news the first international news headlines of bundelkhand
# daily hindi news the first interdistrict place of bundelkhand lrb the first interdistrict terrestrial paper of bundelkhand rrb
# according to pakistan government this is the time seeds of pakistan were sown
# according to the government of pakistan this was the time that the foundation of pakistan had been laid
# as per pakistan government at this time foundation was laid of pakistan
# according to pakistan government at this time only the foundation stone of pakistan was unk
# ...

# %%
# load a clean dataset
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_sentences(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# create a frequency table for all words
def to_vocab(lines):
    vocab = Counter()
    for line in lines:
        tokens = line.split()
        vocab.update(tokens)
    return vocab

# remove all words with a frequency below a threshold
def trim_vocab(vocab, min_occurance):
    tokens = [k for k,c in vocab.items() if c >= min_occurance]
    return set(tokens)

# mark all OOV with "unk" for all lines
def update_dataset(lines, vocab):
    new_lines = list()
    for line in lines:
        new_tokens = list()
        for token in line.split():
            if token in vocab:
                new_tokens.append(token)
            else:
                new_tokens.append('unk')
        new_line = ' '.join(new_tokens)
        new_lines.append(new_line)
    return new_lines



# load French dataset
filename = 'hindi.pkl'
hi_lines = load_clean_sentences(filename)
# calculate vocabulary
hi_vocab = to_vocab(hi_lines)
print('hindi Vocabulary: %d' % len(hi_vocab))
# reduce vocabulary
hi_vocab = trim_vocab(hi_vocab, 3)
print('New hindi Vocabulary: %d' % len(hi_vocab))
# mark out of vocabulary words
hi_lines = update_dataset(hi_lines, hi_vocab)
# save updated dataset
filename = 'hindi_vocab.pkl'
save_clean_sentences(hi_lines, filename)
# spot check
for i in range(1000):
    print(hi_lines[i])
# Out:
# hindi Vocabulary: 21269
# New hindi Vocabulary: 21258
# Saved: hindi_vocab.pkl
# श्रेणी धर्मग्रन्थ
# श्रेणी धर्मग्रन्थ
# श्रेणी धर्मग्रन्थ
# श्रेणी धर्मग्रन्थ
# डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल
# पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।
# पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।
# पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।
# पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।
# Q32008 में मोबाइल फोन विनिर्माताओं के बाजार का हिस्साQ32008 में Nokia दुनिया की सबसे बड़ी मोबाइल फोन निर्माता थी 394 के वैश्विक उपकर्ण बाजार हिस्सेदारी के साथ इसके बाद Samsung LRB 173 RRB Sony Ericsson LRB 86 RRB Motorola LRB 85 RRB और LG Electronics LRB 77 RRB उस समय बेचे गए मोबाइल फोन में से 80 से ऊपर इन निर्माताओं ने बेचा है
# ...

# %%
print (len(hi_lines))
print (len(eng_lines))
# Out:
# 37726
# 37726

# %%
lines = [[eng, hi]
         for eng, hi in zip(eng_lines, hi_lines)]
lines= array(lines)

# %%
def save_clean_data(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

save_clean_data(lines, 'english-hindi.pkl')
# spot check
for i in range(100):
    print('[%s] => [%s]' % (lines[i,0], lines[i,1]))
# Out:
# Saved: english-hindi.pkl
# [series religious book] => [श्रेणी धर्मग्रन्थ]
# [category religious text] => [श्रेणी धर्मग्रन्थ]
# [sat religious book] => [श्रेणी धर्मग्रन्थ]
# [division holy writ] => [श्रेणी धर्मग्रन्थ]
# [unk hindi news bundelkhand s first web based paper] => [डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल]
# [daily hindi news first unk place of bundelkhand] => [डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल]
# [daily hindi news the first international news headlines of bundelkhand] => [डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल]
# [daily hindi news the first interdistrict place of bundelkhand lrb the first interdistrict terrestrial paper of bundelkhand rrb] => [डेली हिन्दी न्यूज बुंदेलखंड का प्रथम अन्तरजालीय स्थल]
# [according to pakistan government this is the time seeds of pakistan were sown] => [पाकिस्तानी सरकार के अनुसार इसी समय पाकिस्तान की नींव डाली गई थी ।]
# ...

# %%
####training on samle data



from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle
 
# load a clean dataset
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))
 
# save a list of clean sentences to file
def save_clean_data(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)
 
 # load dataset
raw_dataset = load_clean_sentences('english-hindi.pkl')
 
# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[9000:]
# save
save_clean_data(dataset, 'english-hindi-both.pkl')
save_clean_data(train, 'english-hindi-train.pkl')
save_clean_data(test, 'english-hindi-test.pkl')
# Out:
# Saved: english-hindi-both.pkl
# Saved: english-hindi-train.pkl
# Saved: english-hindi-test.pkl

# %%
# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
    return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    return model

# load datasets





# prepare validation data
testX = encode_sequences(hindi_tokenizer, hindi_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(hindi_vocab_size, eng_vocab_size, hindi_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=30, batch_size=4, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 8630
# English Max Length: 377
# hindi Vocabulary Size: 9541
# hindi Max Length: 273

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
    return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    return model

# %%
dataset = load_clean_sentences('english-hindi-both.pkl')
train = load_clean_sentences('english-hindi-train.pkl')
test = load_clean_sentences('english-hindi-test.pkl')

# %%
dataset
# Out:
# array([[ 'the tajmahal and other examples are the unk unk of islamic inspired architecture',
#         'ताजमहल और अन्य उदाहरण इस्लाम प्रभावित स्थापत्य कला के अतिसुन्दर नमूने हैं ।'],
#        ['sursaravali', '२ सूरसारावली'],
#        ['example', 'उदाहरण'],
#        ...,
#        ['the cover page of kuraan', 'क़ुरान का आवरण पृष्ठ'],
#        [ 'although many gods and goddesses are worshipped in this religion but in reality it is a unk religion',
#         'हालाँकि इसमें कई देवीदेवताओं की पूजा की जाती है लेकिन वास्तव में यह एकेश्वरवादी धर्म है ।'],
#        ['category religious epic', 'श्रेणी धर्मग्रन्थ']],
#       dtype='<U2180')

# %%
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# Out:
# English Vocabulary Size: 8630
# English Max Length: 377

# %%
# prepare german tokenizer
hindi_tokenizer = create_tokenizer(dataset[:, 1])
hindi_vocab_size = len(hindi_tokenizer.word_index) + 1
hindi_length = max_length(dataset[:, 1])
print('hindi Vocabulary Size: %d' % hindi_vocab_size)
print('hindi Max Length: %d' % (hindi_length))
# Out:
# hindi Vocabulary Size: 9541
# hindi Max Length: 273

# %%
# prepare training data
trainX = encode_sequences(hindi_tokenizer, hindi_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
